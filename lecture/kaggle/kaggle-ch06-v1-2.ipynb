# %% [markdown]
# # 2024/02/14更新
# - 書籍発売後にライブラリのバージョンアップが生じたため、書籍のコードが一部動作しなくなりました
# - このため、書籍のコードが動作するようにコードを一部変更
#     - 変更を最小化するため、基本的には書籍に合わせてライブラリをダウングレード
#     - 名称変更となったライブラリは最新のライブラリ名に変更
# - なお、一部ですが、2024/02/14時点の最新ライブラリでも動作するコードをコメントアウトで同じセルに参考までに掲載しました。

# %%
# 引数が大きく変更されているため、ダウングレードで対応
# 最初に実行してください。
# !pip install pandas==1.3.5
# !pip install lightgbm==3.3.1
# !pip install scikit-learn==1.0.2

# なお、LightGBMの最新版ではCallbackが使われており、過去バージョンと大きく書き方が変化。最新版を使い方を知りたい場合は公式ページを参照してください。
# https://lightgbm.readthedocs.io/en/latest/index.html
# Out:
# Collecting pandas==1.3.5
#   Using cached pandas-1.3.5.tar.gz (4.7 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting numpy>=1.21.0 (from pandas==1.3.5)
#   Using cached numpy-2.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/temmie0232/ML/.venv/lib/python3.12/site-packages (from pandas==1.3.5) (2.9.0.post0)
# Collecting pytz>=2017.3 (from pandas==1.3.5)
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: six>=1.5 in /home/temmie0232/ML/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7.3->pandas==1.3.5) (1.17.0)
# Using cached numpy-2.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.1 MB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Building wheels for collected packages: pandas
#   Building wheel for pandas (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for pandas (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [2434 lines of output]
#       <string>:19: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.linux-x86_64-cpython-312/pandas
#       copying pandas/conftest.py -> build/lib.linux-x86_64-cpython-312/pandas
#       copying pandas/_typing.py -> build/lib.linux-x86_64-cpython-312/pandas
#       copying pandas/_version.py -> build/lib.linux-x86_64-cpython-312/pandas
#       copying pandas/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas
#       copying pandas/testing.py -> build/lib.linux-x86_64-cpython-312/pandas
#       creating build/lib.linux-x86_64-cpython-312/pandas/arrays
#       copying pandas/arrays/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/arrays
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests
#       copying pandas/tests/test_sorting.py -> build/lib.linux-x86_64-cpython-312/pandas/tests
#       copying pandas/tests/test_aggregation.py -> build/lib.linux-x86_64-cpython-312/pandas/tests
#       copying pandas/tests/test_take.py -> build/lib.linux-x86_64-cpython-312/pandas/tests
#       copying pandas/tests/test_downstream.py -> build/lib.linux-x86_64-cpython-312/pandas/tests
#       copying pandas/tests/test_common.py -> build/lib.linux-x86_64-cpython-312/pandas/tests
#       copying pandas/tests/test_register_accessor.py -> build/lib.linux-x86_64-cpython-312/pandas/tests
#       copying pandas/tests/test_expressions.py -> build/lib.linux-x86_64-cpython-312/pandas/tests
#       copying pandas/tests/test_multilevel.py -> build/lib.linux-x86_64-cpython-312/pandas/tests
#       copying pandas/tests/test_errors.py -> build/lib.linux-x86_64-cpython-312/pandas/tests
#       copying pandas/tests/test_algos.py -> build/lib.linux-x86_64-cpython-312/pandas/tests
#       copying pandas/tests/test_nanops.py -> build/lib.linux-x86_64-cpython-312/pandas/tests
#       copying pandas/tests/test_optional_dependency.py -> build/lib.linux-x86_64-cpython-312/pandas/tests
#       copying pandas/tests/test_flags.py -> build/lib.linux-x86_64-cpython-312/pandas/tests
#       copying pandas/tests/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests
#       creating build/lib.linux-x86_64-cpython-312/pandas/errors
#       copying pandas/errors/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/errors
#       creating build/lib.linux-x86_64-cpython-312/pandas/_testing
#       copying pandas/_testing/_io.py -> build/lib.linux-x86_64-cpython-312/pandas/_testing
#       copying pandas/_testing/contexts.py -> build/lib.linux-x86_64-cpython-312/pandas/_testing
#       copying pandas/_testing/asserters.py -> build/lib.linux-x86_64-cpython-312/pandas/_testing
#       copying pandas/_testing/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/_testing
#       copying pandas/_testing/compat.py -> build/lib.linux-x86_64-cpython-312/pandas/_testing
#       copying pandas/_testing/_warnings.py -> build/lib.linux-x86_64-cpython-312/pandas/_testing
#       copying pandas/_testing/_random.py -> build/lib.linux-x86_64-cpython-312/pandas/_testing
#       creating build/lib.linux-x86_64-cpython-312/pandas/tseries
#       copying pandas/tseries/api.py -> build/lib.linux-x86_64-cpython-312/pandas/tseries
#       copying pandas/tseries/offsets.py -> build/lib.linux-x86_64-cpython-312/pandas/tseries
#       copying pandas/tseries/holiday.py -> build/lib.linux-x86_64-cpython-312/pandas/tseries
#       copying pandas/tseries/frequencies.py -> build/lib.linux-x86_64-cpython-312/pandas/tseries
#       copying pandas/tseries/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tseries
#       creating build/lib.linux-x86_64-cpython-312/pandas/util
#       copying pandas/util/_decorators.py -> build/lib.linux-x86_64-cpython-312/pandas/util
#       copying pandas/util/_depr_module.py -> build/lib.linux-x86_64-cpython-312/pandas/util
#       copying pandas/util/_doctools.py -> build/lib.linux-x86_64-cpython-312/pandas/util
#       copying pandas/util/_tester.py -> build/lib.linux-x86_64-cpython-312/pandas/util
#       copying pandas/util/_validators.py -> build/lib.linux-x86_64-cpython-312/pandas/util
#       copying pandas/util/_test_decorators.py -> build/lib.linux-x86_64-cpython-312/pandas/util
#       copying pandas/util/_exceptions.py -> build/lib.linux-x86_64-cpython-312/pandas/util
#       copying pandas/util/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/util
#       copying pandas/util/testing.py -> build/lib.linux-x86_64-cpython-312/pandas/util
#       copying pandas/util/_print_versions.py -> build/lib.linux-x86_64-cpython-312/pandas/util
#       creating build/lib.linux-x86_64-cpython-312/pandas/_config
#       copying pandas/_config/config.py -> build/lib.linux-x86_64-cpython-312/pandas/_config
#       copying pandas/_config/dates.py -> build/lib.linux-x86_64-cpython-312/pandas/_config
#       copying pandas/_config/display.py -> build/lib.linux-x86_64-cpython-312/pandas/_config
#       copying pandas/_config/localization.py -> build/lib.linux-x86_64-cpython-312/pandas/_config
#       copying pandas/_config/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/_config
#       creating build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/arraylike.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/generic.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/roperator.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/aggregation.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/series.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/indexing.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/apply.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/nanops.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/describe.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/flags.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/sorting.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/api.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/common.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/missing.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/construction.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/base.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/frame.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/resample.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/accessor.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/config_init.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/algorithms.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/shared_docs.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/index.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       copying pandas/core/indexers.py -> build/lib.linux-x86_64-cpython-312/pandas/core
#       creating build/lib.linux-x86_64-cpython-312/pandas/compat
#       copying pandas/compat/chainmap.py -> build/lib.linux-x86_64-cpython-312/pandas/compat
#       copying pandas/compat/pickle_compat.py -> build/lib.linux-x86_64-cpython-312/pandas/compat
#       copying pandas/compat/_optional.py -> build/lib.linux-x86_64-cpython-312/pandas/compat
#       copying pandas/compat/pyarrow.py -> build/lib.linux-x86_64-cpython-312/pandas/compat
#       copying pandas/compat/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/compat
#       creating build/lib.linux-x86_64-cpython-312/pandas/_libs
#       copying pandas/_libs/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/_libs
#       creating build/lib.linux-x86_64-cpython-312/pandas/plotting
#       copying pandas/plotting/_core.py -> build/lib.linux-x86_64-cpython-312/pandas/plotting
#       copying pandas/plotting/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/plotting
#       copying pandas/plotting/_misc.py -> build/lib.linux-x86_64-cpython-312/pandas/plotting
#       creating build/lib.linux-x86_64-cpython-312/pandas/io
#       copying pandas/io/pytables.py -> build/lib.linux-x86_64-cpython-312/pandas/io
#       copying pandas/io/gbq.py -> build/lib.linux-x86_64-cpython-312/pandas/io
#       copying pandas/io/orc.py -> build/lib.linux-x86_64-cpython-312/pandas/io
#       copying pandas/io/pickle.py -> build/lib.linux-x86_64-cpython-312/pandas/io
#       copying pandas/io/sql.py -> build/lib.linux-x86_64-cpython-312/pandas/io
#       copying pandas/io/html.py -> build/lib.linux-x86_64-cpython-312/pandas/io
#       copying pandas/io/feather_format.py -> build/lib.linux-x86_64-cpython-312/pandas/io
#       copying pandas/io/stata.py -> build/lib.linux-x86_64-cpython-312/pandas/io
#       copying pandas/io/api.py -> build/lib.linux-x86_64-cpython-312/pandas/io
#       copying pandas/io/common.py -> build/lib.linux-x86_64-cpython-312/pandas/io
#       copying pandas/io/spss.py -> build/lib.linux-x86_64-cpython-312/pandas/io
#       copying pandas/io/parquet.py -> build/lib.linux-x86_64-cpython-312/pandas/io
#       copying pandas/io/date_converters.py -> build/lib.linux-x86_64-cpython-312/pandas/io
#       copying pandas/io/xml.py -> build/lib.linux-x86_64-cpython-312/pandas/io
#       copying pandas/io/clipboards.py -> build/lib.linux-x86_64-cpython-312/pandas/io
#       copying pandas/io/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/io
#       creating build/lib.linux-x86_64-cpython-312/pandas/api
#       copying pandas/api/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/api
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/indexing
#       copying pandas/tests/indexing/test_iat.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexing
#       copying pandas/tests/indexing/test_indexers.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexing
#       copying pandas/tests/indexing/test_floats.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexing
#       copying pandas/tests/indexing/test_categorical.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexing
#       copying pandas/tests/indexing/test_na_indexing.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexing
#       copying pandas/tests/indexing/test_loc.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexing
#       copying pandas/tests/indexing/test_coercion.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexing
#       copying pandas/tests/indexing/test_partial.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexing
#       copying pandas/tests/indexing/test_indexing.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexing
#       copying pandas/tests/indexing/test_at.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexing
#       copying pandas/tests/indexing/test_scalar.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexing
#       copying pandas/tests/indexing/common.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexing
#       copying pandas/tests/indexing/test_check_indexer.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexing
#       copying pandas/tests/indexing/test_chaining_and_caching.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexing
#       copying pandas/tests/indexing/test_iloc.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexing
#       copying pandas/tests/indexing/test_datetime.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexing
#       copying pandas/tests/indexing/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexing
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/dtypes
#       copying pandas/tests/dtypes/test_generic.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/dtypes
#       copying pandas/tests/dtypes/test_common.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/dtypes
#       copying pandas/tests/dtypes/test_inference.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/dtypes
#       copying pandas/tests/dtypes/test_concat.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/dtypes
#       copying pandas/tests/dtypes/test_missing.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/dtypes
#       copying pandas/tests/dtypes/test_dtypes.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/dtypes
#       copying pandas/tests/dtypes/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/dtypes
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/arrays
#       copying pandas/tests/arrays/test_datetimes.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/arrays
#       copying pandas/tests/arrays/test_period.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/arrays
#       copying pandas/tests/arrays/test_ndarray_backed.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/arrays
#       copying pandas/tests/arrays/test_array.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/arrays
#       copying pandas/tests/arrays/test_timedeltas.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/arrays
#       copying pandas/tests/arrays/test_datetimelike.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/arrays
#       copying pandas/tests/arrays/test_numpy.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/arrays
#       copying pandas/tests/arrays/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/arrays
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/construction
#       copying pandas/tests/construction/test_extract_array.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/construction
#       copying pandas/tests/construction/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/construction
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/internals
#       copying pandas/tests/internals/test_api.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/internals
#       copying pandas/tests/internals/test_internals.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/internals
#       copying pandas/tests/internals/test_managers.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/internals
#       copying pandas/tests/internals/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/internals
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/libs
#       copying pandas/tests/libs/test_lib.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/libs
#       copying pandas/tests/libs/test_join.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/libs
#       copying pandas/tests/libs/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/libs
#       copying pandas/tests/libs/test_hashtable.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/libs
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_groupby.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_min_max.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_value_counts.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_nth.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_index_as_string.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_categorical.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_function.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_counting.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_quantile.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_libgroupby.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_size.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_groupby_dropna.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_grouping.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_apply.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_filters.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_bin_groupby.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_timegrouper.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/conftest.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_pipe.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_any_all.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_apply_mutate.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_nunique.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_missing.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_groupby_subclass.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_groupby_shift_diff.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_sample.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_rank.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       copying pandas/tests/groupby/test_allowlist.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/groupby
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/window
#       copying pandas/tests/window/test_groupby.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/window
#       copying pandas/tests/window/test_win_type.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/window
#       copying pandas/tests/window/test_timeseries_window.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/window
#       copying pandas/tests/window/test_numba.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/window
#       copying pandas/tests/window/test_online.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/window
#       copying pandas/tests/window/test_base_indexer.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/window
#       copying pandas/tests/window/test_api.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/window
#       copying pandas/tests/window/test_apply.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/window
#       copying pandas/tests/window/test_expanding.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/window
#       copying pandas/tests/window/conftest.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/window
#       copying pandas/tests/window/test_rolling.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/window
#       copying pandas/tests/window/test_ewm.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/window
#       copying pandas/tests/window/test_pairwise.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/window
#       copying pandas/tests/window/test_dtypes.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/window
#       copying pandas/tests/window/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/window
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/strings
#       copying pandas/tests/strings/test_string_array.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/strings
#       copying pandas/tests/strings/test_get_dummies.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/strings
#       copying pandas/tests/strings/test_extract.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/strings
#       copying pandas/tests/strings/test_api.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/strings
#       copying pandas/tests/strings/conftest.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/strings
#       copying pandas/tests/strings/test_find_replace.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/strings
#       copying pandas/tests/strings/test_split_partition.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/strings
#       copying pandas/tests/strings/test_strings.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/strings
#       copying pandas/tests/strings/test_cat.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/strings
#       copying pandas/tests/strings/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/strings
#       copying pandas/tests/strings/test_case_justify.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/strings
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/config
#       copying pandas/tests/config/test_localization.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/config
#       copying pandas/tests/config/test_config.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/config
#       copying pandas/tests/config/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/config
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/indexes
#       copying pandas/tests/indexes/datetimelike.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexes
#       copying pandas/tests/indexes/test_index_new.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexes
#       copying pandas/tests/indexes/test_numpy_compat.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexes
#       copying pandas/tests/indexes/test_any_index.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexes
#       copying pandas/tests/indexes/test_indexing.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexes
#       copying pandas/tests/indexes/test_base.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexes
#       copying pandas/tests/indexes/test_common.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexes
#       copying pandas/tests/indexes/common.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexes
#       copying pandas/tests/indexes/conftest.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexes
#       copying pandas/tests/indexes/test_engines.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexes
#       copying pandas/tests/indexes/test_frozen.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexes
#       copying pandas/tests/indexes/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexes
#       copying pandas/tests/indexes/test_setops.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexes
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/generic
#       copying pandas/tests/generic/test_duplicate_labels.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/generic
#       copying pandas/tests/generic/test_series.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/generic
#       copying pandas/tests/generic/test_generic.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/generic
#       copying pandas/tests/generic/test_frame.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/generic
#       copying pandas/tests/generic/test_to_xarray.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/generic
#       copying pandas/tests/generic/test_label_or_level_utils.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/generic
#       copying pandas/tests/generic/test_finalize.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/generic
#       copying pandas/tests/generic/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/generic
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/base
#       copying pandas/tests/base/test_value_counts.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/base
#       copying pandas/tests/base/test_conversion.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/base
#       copying pandas/tests/base/test_fillna.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/base
#       copying pandas/tests/base/test_transpose.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/base
#       copying pandas/tests/base/common.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/base
#       copying pandas/tests/base/test_constructors.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/base
#       copying pandas/tests/base/test_unique.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/base
#       copying pandas/tests/base/test_misc.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/base
#       copying pandas/tests/base/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/base
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/reductions
#       copying pandas/tests/reductions/test_stat_reductions.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/reductions
#       copying pandas/tests/reductions/test_reductions.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/reductions
#       copying pandas/tests/reductions/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/reductions
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/tseries
#       copying pandas/tests/tseries/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/tseries
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/test_assert_attr_equal.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/test_assert_extension_array_equal.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/test_show_versions.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/test_assert_frame_equal.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/test_numba.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/test_deprecate_kwarg.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/test_hashing.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/test_assert_interval_array_equal.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/test_assert_categorical_equal.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/test_assert_series_equal.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/test_assert_produces_warning.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/conftest.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/test_validate_args_and_kwargs.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/test_assert_numpy_array_equal.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/test_validate_args.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/test_assert_almost_equal.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/test_deprecate.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/test_doc.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/test_assert_index_equal.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/test_deprecate_nonkeyword_arguments.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/test_validate_kwargs.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/test_util.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       copying pandas/tests/util/test_safe_import.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/util
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/reshape
#       copying pandas/tests/reshape/test_union_categoricals.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/reshape
#       copying pandas/tests/reshape/test_get_dummies.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/reshape
#       copying pandas/tests/reshape/test_crosstab.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/reshape
#       copying pandas/tests/reshape/test_pivot_multilevel.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/reshape
#       copying pandas/tests/reshape/test_melt.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/reshape
#       copying pandas/tests/reshape/test_cut.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/reshape
#       copying pandas/tests/reshape/test_qcut.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/reshape
#       copying pandas/tests/reshape/test_pivot.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/reshape
#       copying pandas/tests/reshape/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/reshape
#       copying pandas/tests/reshape/test_util.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/reshape
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/extension
#       copying pandas/tests/extension/test_integer.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/extension
#       copying pandas/tests/extension/test_categorical.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/extension
#       copying pandas/tests/extension/test_period.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/extension
#       copying pandas/tests/extension/test_string.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/extension
#       copying pandas/tests/extension/test_interval.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/extension
#       copying pandas/tests/extension/test_sparse.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/extension
#       copying pandas/tests/extension/test_floating.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/extension
#       copying pandas/tests/extension/test_common.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/extension
#       copying pandas/tests/extension/conftest.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/extension
#       copying pandas/tests/extension/test_boolean.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/extension
#       copying pandas/tests/extension/test_numpy.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/extension
#       copying pandas/tests/extension/test_extension.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/extension
#       copying pandas/tests/extension/test_datetime.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/extension
#       copying pandas/tests/extension/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/extension
#       copying pandas/tests/extension/test_external_block.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/extension
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/scalar
#       copying pandas/tests/scalar/test_na_scalar.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/scalar
#       copying pandas/tests/scalar/test_nat.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/scalar
#       copying pandas/tests/scalar/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/scalar
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/arithmetic
#       copying pandas/tests/arithmetic/test_object.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/arithmetic
#       copying pandas/tests/arithmetic/test_categorical.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/arithmetic
#       copying pandas/tests/arithmetic/test_array_ops.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/arithmetic
#       copying pandas/tests/arithmetic/test_period.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/arithmetic
#       copying pandas/tests/arithmetic/test_interval.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/arithmetic
#       copying pandas/tests/arithmetic/test_timedelta64.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/arithmetic
#       copying pandas/tests/arithmetic/common.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/arithmetic
#       copying pandas/tests/arithmetic/conftest.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/arithmetic
#       copying pandas/tests/arithmetic/test_numeric.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/arithmetic
#       copying pandas/tests/arithmetic/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/arithmetic
#       copying pandas/tests/arithmetic/test_datetime64.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/arithmetic
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/plotting
#       copying pandas/tests/plotting/test_groupby.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/plotting
#       copying pandas/tests/plotting/test_series.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/plotting
#       copying pandas/tests/plotting/test_hist_method.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/plotting
#       copying pandas/tests/plotting/test_converter.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/plotting
#       copying pandas/tests/plotting/test_style.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/plotting
#       copying pandas/tests/plotting/test_common.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/plotting
#       copying pandas/tests/plotting/common.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/plotting
#       copying pandas/tests/plotting/test_datetimelike.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/plotting
#       copying pandas/tests/plotting/test_misc.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/plotting
#       copying pandas/tests/plotting/test_backend.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/plotting
#       copying pandas/tests/plotting/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/plotting
#       copying pandas/tests/plotting/test_boxplot_method.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/plotting
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/frame
#       copying pandas/tests/frame/test_npfuncs.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/frame
#       copying pandas/tests/frame/test_validate.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/frame
#       copying pandas/tests/frame/test_ufunc.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/frame
#       copying pandas/tests/frame/test_stack_unstack.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/frame
#       copying pandas/tests/frame/test_repr_info.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/frame
#       copying pandas/tests/frame/test_iteration.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/frame
#       copying pandas/tests/frame/test_api.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/frame
#       copying pandas/tests/frame/test_unary.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/frame
#       copying pandas/tests/frame/test_logical_ops.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/frame
#       copying pandas/tests/frame/test_block_internals.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/frame
#       copying pandas/tests/frame/test_cumulative.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/frame
#       copying pandas/tests/frame/common.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/frame
#       copying pandas/tests/frame/conftest.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/frame
#       copying pandas/tests/frame/test_constructors.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/frame
#       copying pandas/tests/frame/test_nonunique_indexes.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/frame
#       copying pandas/tests/frame/test_query_eval.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/frame
#       copying pandas/tests/frame/test_reductions.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/frame
#       copying pandas/tests/frame/test_alter_axes.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/frame
#       copying pandas/tests/frame/test_arithmetic.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/frame
#       copying pandas/tests/frame/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/frame
#       copying pandas/tests/frame/test_subclass.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/frame
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/series
#       copying pandas/tests/series/test_npfuncs.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/series
#       copying pandas/tests/series/test_validate.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/series
#       copying pandas/tests/series/test_ufunc.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/series
#       copying pandas/tests/series/test_repr.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/series
#       copying pandas/tests/series/test_iteration.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/series
#       copying pandas/tests/series/test_api.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/series
#       copying pandas/tests/series/test_unary.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/series
#       copying pandas/tests/series/test_logical_ops.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/series
#       copying pandas/tests/series/test_cumulative.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/series
#       copying pandas/tests/series/test_constructors.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/series
#       copying pandas/tests/series/test_reductions.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/series
#       copying pandas/tests/series/test_missing.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/series
#       copying pandas/tests/series/test_arithmetic.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/series
#       copying pandas/tests/series/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/series
#       copying pandas/tests/series/test_subclass.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/series
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/resample
#       copying pandas/tests/resample/test_datetime_index.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/resample
#       copying pandas/tests/resample/test_time_grouper.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/resample
#       copying pandas/tests/resample/test_resample_api.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/resample
#       copying pandas/tests/resample/test_base.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/resample
#       copying pandas/tests/resample/conftest.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/resample
#       copying pandas/tests/resample/test_period_index.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/resample
#       copying pandas/tests/resample/test_resampler_grouper.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/resample
#       copying pandas/tests/resample/test_timedelta.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/resample
#       copying pandas/tests/resample/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/resample
#       copying pandas/tests/resample/test_deprecated.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/resample
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/io
#       copying pandas/tests/io/test_orc.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/io
#       copying pandas/tests/io/test_spss.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/io
#       copying pandas/tests/io/generate_legacy_storage_files.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/io
#       copying pandas/tests/io/test_compression.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/io
#       copying pandas/tests/io/test_feather.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/io
#       copying pandas/tests/io/test_date_converters.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/io
#       copying pandas/tests/io/test_clipboard.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/io
#       copying pandas/tests/io/test_sql.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/io
#       copying pandas/tests/io/test_gbq.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/io
#       copying pandas/tests/io/test_parquet.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/io
#       copying pandas/tests/io/test_pickle.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/io
#       copying pandas/tests/io/test_common.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/io
#       copying pandas/tests/io/conftest.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/io
#       copying pandas/tests/io/test_user_agent.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/io
#       copying pandas/tests/io/test_gcs.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/io
#       copying pandas/tests/io/test_s3.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/io
#       copying pandas/tests/io/test_fsspec.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/io
#       copying pandas/tests/io/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/io
#       copying pandas/tests/io/test_stata.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/io
#       copying pandas/tests/io/test_html.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/io
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/tools
#       copying pandas/tests/tools/test_to_timedelta.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/tools
#       copying pandas/tests/tools/test_to_time.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/tools
#       copying pandas/tests/tools/test_to_datetime.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/tools
#       copying pandas/tests/tools/test_to_numeric.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/tools
#       copying pandas/tests/tools/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/tools
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/apply
#       copying pandas/tests/apply/test_series_apply.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/apply
#       copying pandas/tests/apply/test_frame_apply.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/apply
#       copying pandas/tests/apply/test_frame_transform.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/apply
#       copying pandas/tests/apply/test_series_transform.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/apply
#       copying pandas/tests/apply/common.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/apply
#       copying pandas/tests/apply/conftest.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/apply
#       copying pandas/tests/apply/test_series_apply_relabeling.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/apply
#       copying pandas/tests/apply/test_invalid_arg.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/apply
#       copying pandas/tests/apply/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/apply
#       copying pandas/tests/apply/test_frame_apply_relabeling.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/apply
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/computation
#       copying pandas/tests/computation/test_compat.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/computation
#       copying pandas/tests/computation/test_eval.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/computation
#       copying pandas/tests/computation/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/computation
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/api
#       copying pandas/tests/api/test_types.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/api
#       copying pandas/tests/api/test_api.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/api
#       copying pandas/tests/api/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/api
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/tslibs
#       copying pandas/tests/tslibs/test_timezones.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/tslibs
#       copying pandas/tests/tslibs/test_conversion.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/tslibs
#       copying pandas/tests/tslibs/test_array_to_datetime.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/tslibs
#       copying pandas/tests/tslibs/test_parsing.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/tslibs
#       copying pandas/tests/tslibs/test_api.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/tslibs
#       copying pandas/tests/tslibs/test_ccalendar.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/tslibs
#       copying pandas/tests/tslibs/test_timedeltas.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/tslibs
#       copying pandas/tests/tslibs/test_parse_iso8601.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/tslibs
#       copying pandas/tests/tslibs/test_period_asfreq.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/tslibs
#       copying pandas/tests/tslibs/test_fields.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/tslibs
#       copying pandas/tests/tslibs/test_to_offset.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/tslibs
#       copying pandas/tests/tslibs/test_liboffsets.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/tslibs
#       copying pandas/tests/tslibs/test_libfrequencies.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/tslibs
#       copying pandas/tests/tslibs/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/tslibs
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/indexing/interval
#       copying pandas/tests/indexing/interval/test_interval.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexing/interval
#       copying pandas/tests/indexing/interval/test_interval_new.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexing/interval
#       copying pandas/tests/indexing/interval/__init__.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexing/interval
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/indexing/multiindex
#       copying pandas/tests/indexing/multiindex/test_slice.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/indexing/multiindex
# ...
#       copying pandas/_libs/src/ujson/lib/ultrajson.h -> build/lib.linux-x86_64-cpython-312/pandas/_libs/src/ujson/lib
#       copying pandas/_libs/src/ujson/lib/ultrajsondec.c -> build/lib.linux-x86_64-cpython-312/pandas/_libs/src/ujson/lib
#       copying pandas/_libs/src/ujson/lib/ultrajsonenc.c -> build/lib.linux-x86_64-cpython-312/pandas/_libs/src/ujson/lib
#       creating build/lib.linux-x86_64-cpython-312/pandas/_libs/src/ujson/python
#       copying pandas/_libs/src/ujson/python/JSONtoObj.c -> build/lib.linux-x86_64-cpython-312/pandas/_libs/src/ujson/python
#       copying pandas/_libs/src/ujson/python/date_conversions.c -> build/lib.linux-x86_64-cpython-312/pandas/_libs/src/ujson/python
#       copying pandas/_libs/src/ujson/python/date_conversions.h -> build/lib.linux-x86_64-cpython-312/pandas/_libs/src/ujson/python
#       copying pandas/_libs/src/ujson/python/objToJSON.c -> build/lib.linux-x86_64-cpython-312/pandas/_libs/src/ujson/python
#       copying pandas/_libs/src/ujson/python/ujson.c -> build/lib.linux-x86_64-cpython-312/pandas/_libs/src/ujson/python
#       copying pandas/_libs/src/ujson/python/version.h -> build/lib.linux-x86_64-cpython-312/pandas/_libs/src/ujson/python
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/io/data
#       copying pandas/tests/io/data/gbq_fake_job.txt -> build/lib.linux-x86_64-cpython-312/pandas/tests/io/data
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/io/data/fixed_width
#       copying pandas/tests/io/data/fixed_width/fixed_width_format.txt -> build/lib.linux-x86_64-cpython-312/pandas/tests/io/data/fixed_width
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/io/data/legacy_pickle/1.2.4
#       copying pandas/tests/io/data/legacy_pickle/1.2.4/empty_frame_v1_2_4-GH#42345.pkl -> build/lib.linux-x86_64-cpython-312/pandas/tests/io/data/legacy_pickle/1.2.4
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/io/data/parquet
#       copying pandas/tests/io/data/parquet/simple.parquet -> build/lib.linux-x86_64-cpython-312/pandas/tests/io/data/parquet
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/io/data/pickle
#       copying pandas/tests/io/data/pickle/test_mi_py27.pkl -> build/lib.linux-x86_64-cpython-312/pandas/tests/io/data/pickle
#       copying pandas/tests/io/data/pickle/test_py27.pkl -> build/lib.linux-x86_64-cpython-312/pandas/tests/io/data/pickle
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/io/data/xml
#       copying pandas/tests/io/data/xml/baby_names.xml -> build/lib.linux-x86_64-cpython-312/pandas/tests/io/data/xml
#       copying pandas/tests/io/data/xml/books.xml -> build/lib.linux-x86_64-cpython-312/pandas/tests/io/data/xml
#       copying pandas/tests/io/data/xml/cta_rail_lines.kml -> build/lib.linux-x86_64-cpython-312/pandas/tests/io/data/xml
#       copying pandas/tests/io/data/xml/flatten_doc.xsl -> build/lib.linux-x86_64-cpython-312/pandas/tests/io/data/xml
#       copying pandas/tests/io/data/xml/row_field_output.xsl -> build/lib.linux-x86_64-cpython-312/pandas/tests/io/data/xml
#       creating build/lib.linux-x86_64-cpython-312/pandas/tests/io/xml
#       copying pandas/tests/io/xml/test_to_xml.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/io/xml
#       copying pandas/tests/io/xml/test_xml.py -> build/lib.linux-x86_64-cpython-312/pandas/tests/io/xml
#       copying pandas/_libs/window/aggregations.pyi -> build/lib.linux-x86_64-cpython-312/pandas/_libs/window
#       copying pandas/_libs/window/aggregations.pyx -> build/lib.linux-x86_64-cpython-312/pandas/_libs/window
#       copying pandas/_libs/window/indexers.pyi -> build/lib.linux-x86_64-cpython-312/pandas/_libs/window
#       copying pandas/_libs/window/indexers.pyx -> build/lib.linux-x86_64-cpython-312/pandas/_libs/window
#       copying pandas/_libs/tslibs/base.pxd -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/base.pyx -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/ccalendar.pxd -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/ccalendar.pyi -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/ccalendar.pyx -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/conversion.pxd -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/conversion.pyi -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/conversion.pyx -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/dtypes.pxd -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/dtypes.pyi -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/dtypes.pyx -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/fields.pyi -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/fields.pyx -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/nattype.pxd -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/nattype.pyi -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/nattype.pyx -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/np_datetime.pxd -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/np_datetime.pyx -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/offsets.pxd -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/offsets.pyx -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/parsing.pxd -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/parsing.pyi -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/parsing.pyx -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/period.pxd -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/period.pyi -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/period.pyx -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/strptime.pyi -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/strptime.pyx -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/timedeltas.pxd -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/timedeltas.pyi -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/timedeltas.pyx -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/timestamps.pxd -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/timestamps.pyi -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/timestamps.pyx -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/timezones.pxd -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/timezones.pyi -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/timezones.pyx -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/tzconversion.pxd -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/tzconversion.pyi -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/tzconversion.pyx -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/util.pxd -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/vectorized.pyi -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/vectorized.pyx -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs
#       creating build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs/src/datetime
#       copying pandas/_libs/tslibs/src/datetime/np_datetime.c -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs/src/datetime
#       copying pandas/_libs/tslibs/src/datetime/np_datetime.h -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs/src/datetime
#       copying pandas/_libs/tslibs/src/datetime/np_datetime_strings.c -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs/src/datetime
#       copying pandas/_libs/tslibs/src/datetime/np_datetime_strings.h -> build/lib.linux-x86_64-cpython-312/pandas/_libs/tslibs/src/datetime
#       creating build/lib.linux-x86_64-cpython-312/pandas/io/formats/templates
#       copying pandas/io/formats/templates/html.tpl -> build/lib.linux-x86_64-cpython-312/pandas/io/formats/templates
#       copying pandas/io/formats/templates/html_style.tpl -> build/lib.linux-x86_64-cpython-312/pandas/io/formats/templates
#       copying pandas/io/formats/templates/html_table.tpl -> build/lib.linux-x86_64-cpython-312/pandas/io/formats/templates
#       copying pandas/io/formats/templates/latex.tpl -> build/lib.linux-x86_64-cpython-312/pandas/io/formats/templates
#       copying pandas/io/sas/sas.pyx -> build/lib.linux-x86_64-cpython-312/pandas/io/sas
#       UPDATING build/lib.linux-x86_64-cpython-312/pandas/_version.py
#       set build/lib.linux-x86_64-cpython-312/pandas/_version.py to '1.3.5'
#       running build_ext
#       building 'pandas._libs.algos' extension
#       creating build/temp.linux-x86_64-cpython-312/pandas/_libs
#       x86_64-linux-gnu-gcc -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DNPY_NO_DEPRECATED_API=0 -I./pandas/_libs -Ipandas/_libs/src/klib -I/tmp/pip-build-env-pyf6tlq_/overlay/lib/python3.12/site-packages/numpy/core/include -I/home/temmie0232/ML/.venv/include -I/usr/include/python3.12 -c pandas/_libs/algos.c -o build/temp.linux-x86_64-cpython-312/pandas/_libs/algos.o
#       pandas/_libs/algos.c:42:10: fatal error: Python.h: No such file or directory
#          42 | #include "Python.h"
#             |          ^~~~~~~~~~
#       compilation terminated.
#       error: command '/usr/bin/x86_64-linux-gnu-gcc' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pandas
# Failed to build pandas
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (pandas)
# Collecting lightgbm==3.3.1
#   Using cached lightgbm-3.3.1-py3-none-manylinux1_x86_64.whl.metadata (15 kB)
# Collecting wheel (from lightgbm==3.3.1)
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting numpy (from lightgbm==3.3.1)
#   Using cached numpy-2.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting scipy (from lightgbm==3.3.1)
#   Using cached scipy-1.14.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting scikit-learn!=0.22.0 (from lightgbm==3.3.1)
#   Using cached scikit_learn-1.6.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting joblib>=1.2.0 (from scikit-learn!=0.22.0->lightgbm==3.3.1)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn!=0.22.0->lightgbm==3.3.1)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Using cached lightgbm-3.3.1-py3-none-manylinux1_x86_64.whl (2.0 MB)
# Using cached scikit_learn-1.6.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
# Using cached numpy-2.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.1 MB)
# Downloading scipy-1.14.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (40.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 5.9 MB/s eta 0:00:0000:0100:01
# Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: wheel, threadpoolctl, numpy, joblib, scipy, scikit-learn, lightgbm
# Successfully installed joblib-1.4.2 lightgbm-3.3.1 numpy-2.2.0 scikit-learn-1.6.0 scipy-1.14.1 threadpoolctl-3.5.0 wheel-0.45.1
# Collecting scikit-learn==1.0.2
#   Downloading scikit-learn-1.0.2.tar.gz (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 4.2 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [33 lines of output]
#       Traceback (most recent call last):
#         File "/home/temmie0232/ML/.venv/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/home/temmie0232/ML/.venv/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/home/temmie0232/ML/.venv/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 112, in get_requires_for_build_wheel
#           backend = _build_backend()
#                     ^^^^^^^^^^^^^^^^
#         File "/home/temmie0232/ML/.venv/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 77, in _build_backend
#           obj = import_module(mod_path)
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#         File "/usr/lib/python3.12/importlib/__init__.py", line 90, in import_module
#           return _bootstrap._gcd_import(name[level:], package, level)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#         File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#         File "<frozen importlib._bootstrap>", line 1310, in _find_and_load_unlocked
#         File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#         File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#         File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#         File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#         File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#         File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#         File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#         File "/tmp/pip-build-env-abhcq7kz/overlay/lib/python3.12/site-packages/setuptools/__init__.py", line 16, in <module>
#           import setuptools.version
#         File "/tmp/pip-build-env-abhcq7kz/overlay/lib/python3.12/site-packages/setuptools/version.py", line 1, in <module>
#           import pkg_resources
#         File "/tmp/pip-build-env-abhcq7kz/overlay/lib/python3.12/site-packages/pkg_resources/__init__.py", line 2172, in <module>
#           register_finder(pkgutil.ImpImporter, find_on_path)
#                           ^^^^^^^^^^^^^^^^^^^
#       AttributeError: module 'pkgutil' has no attribute 'ImpImporter'. Did you mean: 'zipimporter'?
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %% [markdown]
# # Kaggleで磨く 機械学習の実践力
# # 第6章 モデルチューニング

# %% [markdown]
# # 6.1 LightGBMのハイパーパラメータのチューニング
# ## 6.1.2 ハイパーパラメータの自動チューニング

# %% [markdown]
# #### スクリプト: ライブラリのインポート (スクリプト4-1の再掲)

# %%
import numpy as np
import pandas as pd
import os
import pickle
import gc

# 分布確認
# import pandas_profiling as pdp
import ydata_profiling as pdp # ライブラリ名称が変更になったため

# 可視化
import matplotlib.pyplot as plt

# 前処理
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder, OneHotEncoder

# バリデーション
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, GroupKFold

# 評価指標
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix

# モデリング: lightgbm
import lightgbm as lgb

import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# #### スクリプト: ファイルの読み込み (スクリプト4-2の再掲)

# %%
df_train = pd.read_csv("../input/titanic/train.csv")

# %% [markdown]
# #### スクリプト: データセット作成 (スクリプト4-8の再掲)

# %%
x_train, y_train, id_train = df_train[["Pclass", "Fare"]], \
                             df_train[["Survived"]], \
                             df_train[["PassengerId"]]
print(x_train.shape, y_train.shape, id_train.shape)
# Out:
# (891, 2) (891, 1) (891, 1)

# %% [markdown]
# #### スクリプト6-1: optunaのインポート

# %%
import optuna

# %% [markdown]
# #### スクリプト6-2: 目的関数の定義

# %%
# 探索しないハイパーパラメータ
params_base = {
    "boosting_type": "gbdt",
    "objective": "binary",
    "metric": "auc",
    "learning_rate": 0.02,
    'n_estimators': 100000,
    "bagging_freq": 1,
    "seed": 123,
}

def objective(trial):
    # 探索するハイパーパラメータ
    params_tuning = {
        "num_leaves": trial.suggest_int("num_leaves", 8, 256),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 5, 200),
        "min_sum_hessian_in_leaf": trial.suggest_float("min_sum_hessian_in_leaf", 1e-5, 1e-2, log=True),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.5, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.5, 1.0),
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-2, 1e2, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-2, 1e2, log=True),
    }
    params_tuning.update(params_base)
    
    # モデル学習・評価
    list_metrics = []
    cv = list(StratifiedKFold(n_splits=5, shuffle=True, random_state=123).split(x_train, y_train))
    for nfold in np.arange(5):
        idx_tr, idx_va = cv[nfold][0], cv[nfold][1]
        x_tr, y_tr = x_train.loc[idx_tr, :], y_train.loc[idx_tr, :]
        x_va, y_va = x_train.loc[idx_va, :], y_train.loc[idx_va, :]
        model = lgb.LGBMClassifier(**params_tuning)
        model.fit(x_tr,
                  y_tr,
                  eval_set=[(x_tr,y_tr), (x_va,y_va)],
                  early_stopping_rounds=100,
                  verbose=0,
                 )
#         # 2024/02/14環境で動かしたい場合はこのコードを利用してください。
#         model.fit(x_tr,
#                   y_tr,
#                   eval_set=[(x_tr,y_tr), (x_va,y_va)],
#                   callbacks=[
#                       lgb.early_stopping(stopping_rounds=100, verbose=True),
#                       lgb.log_evaluation(0),
#                   ],
#                  )
        
        y_va_pred = model.predict_proba(x_va)[:,1]
        metric_va = accuracy_score(y_va, np.where(y_va_pred>=0.5, 1, 0))
        list_metrics.append(metric_va)
    
    # 評価値の計算
    metrics = np.mean(list_metrics)
    
    return metrics

# %% [markdown]
# #### スクリプト6-3: 最適化処理（探索の実行）

# %%
sampler = optuna.samplers.TPESampler(seed=123)
study = optuna.create_study(sampler=sampler, direction="maximize")
study.optimize(objective, n_trials=30)
# Out:
# [I 2024-02-14 12:56:15,523] A new study created in memory with name: no-name-7006dc18-ca31-4eff-b0a4-2e2b586d8ce3
# [LightGBM] [Warning] lambda_l1 is set=0.492522233779106, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.492522233779106
# [LightGBM] [Warning] bagging_fraction is set=0.8597344848927815, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8597344848927815
# [LightGBM] [Warning] lambda_l2 is set=83.76388146302445, reg_lambda=0.0 will be ignored. Current value: lambda_l2=83.76388146302445
# [LightGBM] [Warning] feature_fraction is set=0.7756573845414456, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7756573845414456
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=4.792414358623587e-05, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=4.792414358623587e-05
# [LightGBM] [Warning] min_data_in_leaf is set=61, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=61
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l1 is set=0.492522233779106, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.492522233779106
# [LightGBM] [Warning] bagging_fraction is set=0.8597344848927815, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8597344848927815
# [LightGBM] [Warning] lambda_l2 is set=83.76388146302445, reg_lambda=0.0 will be ignored. Current value: lambda_l2=83.76388146302445
# [LightGBM] [Warning] feature_fraction is set=0.7756573845414456, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7756573845414456
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=4.792414358623587e-05, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=4.792414358623587e-05
# [LightGBM] [Warning] min_data_in_leaf is set=61, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=61
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l1 is set=0.492522233779106, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.492522233779106
# [LightGBM] [Warning] bagging_fraction is set=0.8597344848927815, subsample=1.0 will be ignored. Current value: bagging_fraction=0.
colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9720800091019398
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=0.004788147156768277, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=0.004788147156768277
# [LightGBM] [Warning] min_data_in_leaf is set=88, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=88
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2024-02-14 12:56:26,092] Trial 5 finished with value: 0.6587847592743706 and parameters: {'num_leaves': 85, 'min_data_in_leaf': 88, 'min_sum_hessian_in_leaf': 0.004788147156768277, 'feature_fraction': 0.9720800091019398, 'bagging_fraction': 0.7509183379421682, 'lambda_l1': 3.1319282717196035, 'lambda_l2': 0.029005047452739414}. Best is trial 3 with value: 0.6722302429226037.
# [LightGBM] [Warning] lambda_l1 is set=87.54657140659076, reg_alpha=0.0 will be ignored. Current value: lambda_l1=87.54657140659076
# [LightGBM] [Warning] bagging_fraction is set=0.7415171321313522, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7415171321313522
# [LightGBM] [Warning] lambda_l2 is set=1.1965765212602313, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.1965765212602313
# [LightGBM] [Warning] feature_fraction is set=0.6252276826982534, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6252276826982534
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=0.003971252247766701, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=0.003971252247766701
# [LightGBM] [Warning] min_data_in_leaf is set=86, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=86
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l1 is set=87.54657140659076, reg_alpha=0.0 will be ignored. Current value: lambda_l1=87.54657140659076
# [LightGBM] [Warning] bagging_fraction is set=0.7415171321313522, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7415171321313522
# [LightGBM] [Warning] lambda_l2 is set=1.1965765212602313, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.1965765212602313
# [LightGBM] [Warning] feature_fraction is set=0.6252276826982534, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6252276826982534
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=0.003971252247766701, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=0.003971252247766701
# [LightGBM] [Warning] min_data_in_leaf is set=86, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=86
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l1 is set=87.54657140659076, reg_alpha=0.0 will be ignored. Current value: lambda_l1=87.54657140659076
# [LightGBM] [Warning] bagging_fraction is set=0.7415171321313522, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7415171321313522
# [LightGBM] [Warning] lambda_l2 is set=1.1965765212602313, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.1965765212602313
# [LightGBM] [Warning] feature_fraction is set=0.6252276826982534, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6252276826982534
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=0.003971252247766701, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=0.003971252247766701
# [LightGBM] [Warning] min_data_in_leaf is set=86, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=86
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2024-02-14 12:56:26,459] Trial 6 finished with value: 0.6161634548992531 and parameters: {'num_leaves': 87, 'min_data_in_leaf': 86, 'min_sum_hessian_in_leaf': 0.003971252247766701, 'feature_fraction': 0.6252276826982534, 'bagging_fraction': 0.7415171321313522, 'lambda_l1': 87.54657140659076, 'lambda_l2': 1.1965765212602313}. Best is trial 3 with value: 0.6722302429226037.
# [LightGBM] [Warning] lambda_l1 is set=87.54657140659076, reg_alpha=0.0 will be ignored. Current value: lambda_l1=87.54657140659076
# [LightGBM] [Warning] bagging_fraction is set=0.7415171321313522, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7415171321313522
# [LightGBM] [Warning] lambda_l2 is set=1.1965765212602313, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.1965765212602313
# [LightGBM] [Warning] feature_fraction is set=0.6252276826982534, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6252276826982534
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=0.003971252247766701, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=0.003971252247766701
# [LightGBM] [Warning] min_data_in_leaf is set=86, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=86
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l1 is set=87.54657140659076, reg_alpha=0.0 will be ignored. Current value: lambda_l1=87.54657140659076
# [LightGBM] [Warning] bagging_fraction is set=0.7415171321313522, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7415171321313522
# [LightGBM] [Warning] lambda_l2 is set=1.1965765212602313, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.1965765212602313
# [LightGBM] [Warning] feature_fraction is set=0.6252276826982534, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6252276826982534
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=0.003971252247766701, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=0
subsample=1.0 will be ignored. Current value: bagging_fraction=0.9850169158486759
# [LightGBM] [Warning] lambda_l2 is set=32.318206202200265, reg_lambda=0.0 will be ignored. Current value: lambda_l2=32.318206202200265
# [LightGBM] [Warning] feature_fraction is set=0.7116385045852216, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7116385045852216
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=8.505644215173895e-05, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=8.505644215173895e-05
# [LightGBM] [Warning] min_data_in_leaf is set=196, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=196
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l1 is set=0.02276315503480073, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.02276315503480073
# [LightGBM] [Warning] bagging_fraction is set=0.9850169158486759, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9850169158486759
# [LightGBM] [Warning] lambda_l2 is set=32.318206202200265, reg_lambda=0.0 will be ignored. Current value: lambda_l2=32.318206202200265
# [LightGBM] [Warning] feature_fraction is set=0.7116385045852216, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7116385045852216
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=8.505644215173895e-05, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=8.505644215173895e-05
# [LightGBM] [Warning] min_data_in_leaf is set=196, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=196
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l1 is set=0.02276315503480073, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.02276315503480073
# [LightGBM] [Warning] bagging_fraction is set=0.9850169158486759, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9850169158486759
# [LightGBM] [Warning] lambda_l2 is set=32.318206202200265, reg_lambda=0.0 will be ignored. Current value: lambda_l2=32.318206202200265
# [LightGBM] [Warning] feature_fraction is set=0.7116385045852216, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7116385045852216
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=8.505644215173895e-05, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=8.505644215173895e-05
# [LightGBM] [Warning] min_data_in_leaf is set=196, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=196
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l1 is set=0.02276315503480073, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.02276315503480073
# [LightGBM] [Warning] bagging_fraction is set=0.9850169158486759, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9850169158486759
# [LightGBM] [Warning] lambda_l2 is set=32.318206202200265, reg_lambda=0.0 will be ignored. Current value: lambda_l2=32.318206202200265
# [LightGBM] [Warning] feature_fraction is set=0.7116385045852216, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7116385045852216
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=8.505644215173895e-05, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=8.505644215173895e-05
# [LightGBM] [Warning] min_data_in_leaf is set=196, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=196
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l1 is set=0.02276315503480073, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.02276315503480073
# [LightGBM] [Warning] bagging_fraction is set=0.9850169158486759, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9850169158486759
# [LightGBM] [Warning] lambda_l2 is set=32.318206202200265, reg_lambda=0.0 will be ignored. Current value: lambda_l2=32.318206202200265
# [LightGBM] [Warning] feature_fraction is set=0.7116385045852216, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7116385045852216
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=8.505644215173895e-05, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=8.505644215173895e-05
# [LightGBM] [Warning] min_data_in_leaf is set=196, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=196
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2024-02-14 12:57:16,166] Trial 29 finished with value: 0.6587470968551881 and parameters: {'num_leaves': 161, 'min_data_in_leaf': 196, 'min_sum_hessian_in_leaf': 8.505644215173895e-05, 'feature_fraction': 0.7116385045852216, 'bagging_fraction': 0.9850169158486759, 'lambda_l1': 0.02276315503480073, 'lambda_l2': 32.318206202200265}. Best is trial 7 with value: 0.6992530286862093.

# %% [markdown]
# #### スクリプト6-4: 探索結果の確認

# %%
trial = study.best_trial
print("acc(best)={:.4f}".format(trial.value))
display(trial.params)
# Out:
# acc(best)=0.6993
# {'num_leaves': 160,
#  'min_data_in_leaf': 28,
#  'min_sum_hessian_in_leaf': 0.0030131614432849746,
#  'feature_fraction': 0.8015300642054637,
#  'bagging_fraction': 0.7725340032332324,
#  'lambda_l1': 0.23499322154972468,
#  'lambda_l2': 0.1646202117975735}

# %% [markdown]
# #### スクリプト6-5: ベストなハイパーパラメータの取得

# %%
params_best = trial.params
params_best.update(params_base)
display(params_best)
# Out:
# {'num_leaves': 160,
#  'min_data_in_leaf': 28,
#  'min_sum_hessian_in_leaf': 0.0030131614432849746,
#  'feature_fraction': 0.8015300642054637,
#  'bagging_fraction': 0.7725340032332324,
#  'lambda_l1': 0.23499322154972468,
#  'lambda_l2': 0.1646202117975735,
#  'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'metric': 'auc',
#  'learning_rate': 0.02,
#  'n_estimators': 100000,
#  'bagging_freq': 1,
#  'seed': 123}

# %% [markdown]
# # 6.2 LightGBM以外のモデル利用
# ## 6.2.1 scikit-learnの各種モデル

# %% [markdown]
# ### Titanicデータを用いた例：ロジスティック回帰
# #### スクリプト6-6: ファイル読み込みとデータセット作成

# %%
# ファイル読み込み
df_train = pd.read_csv("../input/titanic/train.csv")

# データセット作成
x_train = df_train[["Pclass", "Age", "Embarked"]]
y_train = df_train[["Survived"]]

# %%
# 欠損値の確認
x_train.isnull().sum()
# Out:
# Pclass        0
# Age         177
# Embarked      2
# dtype: int64

# %% [markdown]
# #### スクリプト6-7: 欠損値の補間

# %%
# 欠損値補間：数値データ
x_train["Age"] = x_train["Age"].fillna(x_train["Age"].mean())

# 欠損値補間：カテゴリ変数
x_train["Embarked"] = x_train["Embarked"].fillna(x_train["Embarked"].mode()[0])

# %% [markdown]
# #### スクリプト6-8: カテゴリ変数の数値化（one-hot-encoding）

# %%
ohe = OneHotEncoder()
ohe.fit(x_train[["Embarked"]])
df_embarked = pd.DataFrame(
    ohe.transform(x_train[["Embarked"]]).toarray(), 
    columns=["Embarked_{}".format(col) for col in ohe.categories_[0]])

x_train = pd.concat([x_train, df_embarked], axis=1)
x_train = x_train.drop(columns=["Embarked"])

# %% [markdown]
# #### スクリプト6-9: 数値データの正規化

# %%
x_train["Pclass"] = (x_train["Pclass"] -x_train["Pclass"].min()) / (x_train["Pclass"].max() - x_train["Pclass"].min()) 
x_train["Age"] = (x_train["Age"] -x_train["Age"].min()) / (x_train["Age"].max() - x_train["Age"].min())

# %% [markdown]
# #### スクリプト6-10: 学習データと検証データの分割（ホールドアウト検証）

# %%
x_tr, x_va, y_tr, y_va = train_test_split(x_train, y_train, test_size=0.2, stratify=y_train, random_state=123)
print(x_tr.shape, x_va.shape, y_tr.shape, y_va.shape)
# Out:
# (712, 5) (179, 5) (712, 1) (179, 1)

# %% [markdown]
# #### スクリプト6-11: LogisticRegression

# %%
# モデル定義
from sklearn.linear_model import LogisticRegression
model_logis = LogisticRegression()

# 学習
model_logis.fit(x_tr, y_tr)

# 予測
y_va_pred = model_logis.predict(x_va)
print("accuracy:{:.4f}".format(accuracy_score(y_va, y_va_pred)))
print(y_va_pred[:5])
# Out:
# accuracy:0.7263
# [0 1 0 1 0]

# %% [markdown]
# #### スクリプト6-12: 確率値の取得

# %%
y_va_pred_proba = model_logis.predict_proba(x_va)
print(y_va_pred_proba[:5, :])
# Out:
# [[0.83621285 0.16378715]
#  [0.23058311 0.76941689]
#  [0.83244141 0.16755859]
#  [0.32227072 0.67772928]
#  [0.62569522 0.37430478]]

# %% [markdown]
# ### Titanicデータを用いた例：SVM
# #### スクリプト6-13: SVM

# %%
# モデル定義
from sklearn.svm import SVC
model_svm = SVC(C=1.0, random_state=123, probability=True)

# 学習
model_svm.fit(x_tr, y_tr)

# 予測
y_va_pred = model_svm.predict(x_va)
print("accuracy:{:.4f}".format(accuracy_score(y_va, y_va_pred)))
print(y_va_pred[:5])

# 確率値の取得
y_va_pred_proba = model_svm.predict_proba(x_va)
print(y_va_pred_proba[:5, :])
# Out:
# accuracy:0.7151
# [0 1 0 1 0]
# [[0.73985924 0.26014076]
#  [0.28242534 0.71757466]
#  [0.73986177 0.26013823]
#  [0.26828214 0.73171786]
#  [0.58950192 0.41049808]]

# %% [markdown]
# ## 6.2.2 ニューラルネットワーク

# %% [markdown]
# ### ニューラルネットワークの適用例：①全結合層のみのネットワークモデル
# #### スクリプト6-14: ライブラリのインポート

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.layers import Embedding, Flatten, Concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, LearningRateScheduler
from tensorflow.keras.optimizers import Adam, SGD
# Out:
# 2024-02-14 12:57:21.602077: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-14 12:57:21.602277: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-14 12:57:21.794351: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# #### スクリプト6-15: tensorflowの再現性のためのシード指定

# %%
def seed_everything(seed):
    import random
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    session_conf = tf.compat.v1.ConfigProto(
        intra_op_parallelism_threads=1,
        inter_op_parallelism_threads=1
    )
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %% [markdown]
# #### スクリプト6-16: ファイルの読み込みとデータセット作成

# %%
# ファイル読み込み
df_train = pd.read_csv("../input/titanic/train.csv")

# データセット作成
x_train = df_train[["Pclass", "Age", "Embarked"]]
y_train = df_train[["Survived"]]

# %% [markdown]
# #### スクリプト6-17: 数値データの前処理

# %%
# 欠損値補間
x_train["Age"] = x_train["Age"].fillna(x_train["Age"].mean())

# 正規化
for col in ["Pclass", "Age"]:
    value_min = x_train[col].min()
    value_max = x_train[col].max()
    x_train[col] = (x_train[col] - value_min) / (value_max - value_min)

# %% [markdown]
# #### スクリプト6-18: カテゴリ変数の前処理

# %%
# 欠損値補間
x_train["Embarked"] = x_train["Embarked"].fillna(x_train["Embarked"].mode()[0])

# one-hot-encoding
ohe = OneHotEncoder()
ohe.fit(x_train[["Embarked"]])
df_embarked = pd.DataFrame(ohe.transform(x_train[["Embarked"]]).toarray(), 
                           columns=["Embarked_{}".format(col) for col in ohe.categories_[0]])
x_train = pd.concat([x_train.drop(columns=["Embarked"]), 
                     df_embarked], axis=1)

# %% [markdown]
# #### スクリプト6-19: 学習データと検証データの分割

# %%
x_tr, x_va, y_tr, y_va = train_test_split(x_train, y_train, test_size=0.2, stratify=y_train, random_state=123)
print(x_tr.shape, x_va.shape, y_tr.shape, y_va.shape)
# Out:
# (712, 5) (179, 5) (712, 1) (179, 1)

# %% [markdown]
# #### スクリプト6-20: モデル定義

# %%
def create_model():
    input_num = Input(shape=(5,))
    x_num = Dense(10, activation="relu")(input_num)
    x_num = BatchNormalization()(x_num)
    x_num = Dropout(0.3)(x_num)
    x_num = Dense(10, activation="relu")(x_num)
    x_num = BatchNormalization()(x_num)
    x_num = Dropout(0.2)(x_num)
    x_num = Dense(5, activation="relu")(x_num)
    x_num = BatchNormalization()(x_num)
    x_num = Dropout(0.1)(x_num)
    out = Dense(1, activation="sigmoid")(x_num)

    model = Model(inputs=input_num,
                  outputs=out,
                 )

    model.compile(
        optimizer="Adam",
        loss="binary_crossentropy",
        metrics=["binary_crossentropy"],
    )
    
    return model

model = create_model()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5)]               0
#
#  dense (Dense)               (None, 10)                60
#
#  batch_normalization (Batch  (None, 10)                40
#  Normalization)
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 10)                110
#
#  batch_normalization_1 (Bat  (None, 10)                40
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 5)                 55
#
#  batch_normalization_2 (Bat  (None, 5)                 20
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 5)                 0
#
#  dense_3 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 331 (1.29 KB)
# Trainable params: 281 (1.10 KB)
# Non-trainable params: 50 (200.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### スクリプト6-21: モデル学習

# %%
seed_everything(seed=123)
model = create_model()
model.fit(x=x_tr,
          y=y_tr,
          validation_data=(x_va, y_va),
          batch_size=8,
          epochs=10000,
          callbacks=[
              ModelCheckpoint(filepath="model_keras.h5", monitor="val_loss", mode="min", verbose=1, save_best_only=True, save_weights_only=True),
              EarlyStopping(monitor="val_loss", mode="min", min_delta=0, patience=10, verbose=1, restore_best_weights=True),
              ReduceLROnPlateau(monitor="val_loss", mode="min", factor=0.1, patience=5, verbose=1),
          ],
          verbose=1,
         )
# Out:
# Epoch 1/10000
# 76/89 [========================>.....] - ETA: 0s - loss: 0.7278 - binary_crossentropy: 0.7278
# Epoch 1: val_loss improved from inf to 0.68176, saving model to model_keras.h5
# 89/89 [==============================] - 3s 7ms/step - loss: 0.7268 - binary_crossentropy: 0.7268 - val_loss: 0.6818 - val_binary_crossentropy: 0.6818 - lr: 0.0010
# Epoch 2/10000
# 72/89 [=======================>......] - ETA: 0s - loss: 0.6810 - binary_crossentropy: 0.6810
# Epoch 2: val_loss improved from 0.68176 to 0.66805, saving model to model_keras.h5
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6753 - binary_crossentropy: 0.6753 - val_loss: 0.6681 - val_binary_crossentropy: 0.6681 - lr: 0.0010
# Epoch 3/10000
# 74/89 [=======================>......] - ETA: 0s - loss: 0.6898 - binary_crossentropy: 0.6898
# Epoch 3: val_loss improved from 0.66805 to 0.65480, saving model to model_keras.h5
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6801 - binary_crossentropy: 0.6801 - val_loss: 0.6548 - val_binary_crossentropy: 0.6548 - lr: 0.0010
# Epoch 4/10000
# 69/89 [======================>.......] - ETA: 0s - loss: 0.6528 - binary_crossentropy: 0.6528
# Epoch 4: val_loss improved from 0.65480 to 0.63951, saving model to model_keras.h5
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6526 - binary_crossentropy: 0.6526 - val_loss: 0.6395 - val_binary_crossentropy: 0.6395 - lr: 0.0010
# Epoch 5/10000
# 77/89 [========================>.....] - ETA: 0s - loss: 0.6588 - binary_crossentropy: 0.6588
# Epoch 5: val_loss improved from 0.63951 to 0.62343, saving model to model_keras.h5
# 89/89 [==============================] - 0s 4ms/step - loss: 0.6539 - binary_crossentropy: 0.6539 - val_loss: 0.6234 - val_binary_crossentropy: 0.6234 - lr: 0.0010
# Epoch 6/10000
# 86/89 [===========================>..] - ETA: 0s - loss: 0.6588 - binary_crossentropy: 0.6588
# Epoch 6: val_loss improved from 0.62343 to 0.61811, saving model to model_keras.h5
# 89/89 [==============================] - 0s 4ms/step - loss: 0.6614 - binary_crossentropy: 0.6614 - val_loss: 0.6181 - val_binary_crossentropy: 0.6181 - lr: 0.0010
# Epoch 7/10000
# 84/89 [===========================>..] - ETA: 0s - loss: 0.6591 - binary_crossentropy: 0.6591
# Epoch 7: val_loss improved from 0.61811 to 0.61267, saving model to model_keras.h5
# 89/89 [==============================] - 0s 4ms/step - loss: 0.6605 - binary_crossentropy: 0.6605 - val_loss: 0.6127 - val_binary_crossentropy: 0.6127 - lr: 0.0010
# Epoch 8/10000
# 77/89 [========================>.....] - ETA: 0s - loss: 0.6519 - binary_crossentropy: 0.6519
# Epoch 8: val_loss did not improve from 0.61267
# 89/89 [==============================] - 0s 4ms/step - loss: 0.6448 - binary_crossentropy: 0.6448 - val_loss: 0.6185 - val_binary_crossentropy: 0.6185 - lr: 0.0010
# Epoch 9/10000
# 86/89 [===========================>..] - ETA: 0s - loss: 0.6467 - binary_crossentropy: 0.6467
# Epoch 9: val_loss improved from 0.61267 to 0.61192, saving model to model_keras.h5
# 89/89 [==============================] - 0s 4ms/step - loss: 0.6473 - binary_crossentropy: 0.6473 - val_loss: 0.6119 - val_binary_crossentropy: 0.6119 - lr: 0.0010
# Epoch 10/10000
# 78/89 [=========================>....] - ETA: 0s - loss: 0.6284 - binary_crossentropy: 0.6284
# Epoch 10: val_loss improved from 0.61192 to 0.60599, saving model to model_keras.h5
# 89/89 [==============================] - 0s 4ms/step - loss: 0.6262 - binary_crossentropy: 0.6262 - val_loss: 0.6060 - val_binary_crossentropy: 0.6060 - lr: 0.0010
# Epoch 11/10000
# 78/89 [=========================>....] - ETA: 0s - loss: 0.6471 - binary_crossentropy: 0.6471
# Epoch 11: val_loss improved from 0.60599 to 0.60516, saving model to model_keras.h5
# 89/89 [==============================] - 0s 4ms/step - loss: 0.6488 - binary_crossentropy: 0.6488 - val_loss: 0.6052 - val_binary_crossentropy: 0.6052 - lr: 0.0010
# Epoch 12/10000
# 80/89 [=========================>....] - ETA: 0s - loss: 0.6392 - binary_crossentropy: 0.6392
# Epoch 12: val_loss did not improve from 0.60516
# 89/89 [==============================] - 0s 4ms/step - loss: 0.6377 - binary_crossentropy: 0.6377 - val_loss: 0.6056 - val_binary_crossentropy: 0.6056 - lr: 0.0010
# Epoch 13/10000
# 73/89 [=======================>......] - ETA: 0s - loss: 0.6475 - binary_crossentropy: 0.6475
# Epoch 13: val_loss improved from 0.60516 to 0.60494, saving model to model_keras.h5
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6441 - binary_crossentropy: 0.6441 - val_loss: 0.6049 - val_binary_crossentropy: 0.6049 - lr: 0.0010
# Epoch 14/10000
# 74/89 [=======================>......] - ETA: 0s - loss: 0.6242 - binary_crossentropy: 0.6242
# Epoch 14: val_loss improved from 0.60494 to 0.59610, saving model to model_keras.h5
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6208 - binary_crossentropy: 0.6208 - val_loss: 0.5961 - val_binary_crossentropy: 0.5961 - lr: 0.0010
# Epoch 15/10000
# 72/89 [=======================>......] - ETA: 0s - loss: 0.6151 - binary_crossentropy: 0.6151
# Epoch 15: val_loss improved from 0.59610 to 0.59132, saving model to model_keras.h5
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6176 - binary_crossentropy: 0.6176 - val_loss: 0.5913 - val_binary_crossentropy: 0.5913 - lr: 0.0010
# Epoch 16/10000
# 71/89 [======================>.......] - ETA: 0s - loss: 0.6043 - binary_crossentropy: 0.6043
# Epoch 16: val_loss improved from 0.59132 to 0.58463, saving model to model_keras.h5
# 89/89 [==============================] - 0s 4ms/step - loss: 0.6098 - binary_crossentropy: 0.6098 - val_loss: 0.5846 - val_binary_crossentropy: 0.5846 - lr: 0.0010
# Epoch 17/10000
# 83/89 [==========================>...] - ETA: 0s - loss: 0.6203 - binary_crossentropy: 0.6203
# Epoch 17: val_loss did not improve from 0.58463
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6251 - binary_crossentropy: 0.6251 - val_loss: 0.5897 - val_binary_crossentropy: 0.5897 - lr: 0.0010
# Epoch 18/10000
# 83/89 [==========================>...] - ETA: 0s - loss: 0.6176 - binary_crossentropy: 0.6176
# Epoch 18: val_loss did not improve from 0.58463
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6181 - binary_crossentropy: 0.6181 - val_loss: 0.5878 - val_binary_crossentropy: 0.5878 - lr: 0.0010
# Epoch 19/10000
# 86/89 [===========================>..] - ETA: 0s - loss: 0.6066 - binary_crossentropy: 0.6066
# Epoch 19: val_loss improved from 0.58463 to 0.58410, saving model to model_keras.h5
# 89/89 [==============================] - 0s 4ms/step - loss: 0.6072 - binary_crossentropy: 0.6072 - val_loss: 0.5841 - val_binary_crossentropy: 0.5841 - lr: 0.0010
# Epoch 20/10000
# 81/89 [==========================>...] - ETA: 0s - loss: 0.6239 - binary_crossentropy: 0.6239
# Epoch 20: val_loss did not improve from 0.58410
# 89/89 [==============================] - 0s 4ms/step - loss: 0.6232 - binary_crossentropy: 0.6232 - val_loss: 0.5876 - val_binary_crossentropy: 0.5876 - lr: 0.0010
# Epoch 21/10000
# 80/89 [=========================>....] - ETA: 0s - loss: 0.6328 - binary_crossentropy: 0.6328
# Epoch 21: val_loss did not improve from 0.58410
# 89/89 [==============================] - 0s 4ms/step - loss: 0.6317 - binary_crossentropy: 0.6317 - val_loss: 0.5848 - val_binary_crossentropy: 0.5848 - lr: 0.0010
# Epoch 22/10000
# 84/89 [===========================>..] - ETA: 0s - loss: 0.6281 - binary_crossentropy: 0.6281
# Epoch 22: val_loss improved from 0.58410 to 0.57950, saving model to model_keras.h5
# 89/89 [==============================] - 0s 4ms/step - loss: 0.6258 - binary_crossentropy: 0.6258 - val_loss: 0.5795 - val_binary_crossentropy: 0.5795 - lr: 0.0010
# Epoch 23/10000
# 88/89 [============================>.] - ETA: 0s - loss: 0.6186 - binary_crossentropy: 0.6186
# Epoch 23: val_loss improved from 0.57950 to 0.57822, saving model to model_keras.h5
# 89/89 [==============================] - 0s 4ms/step - loss: 0.6175 - binary_crossentropy: 0.6175 - val_loss: 0.5782 - val_binary_crossentropy: 0.5782 - lr: 0.0010
# Epoch 24/10000
# 73/89 [=======================>......] - ETA: 0s - loss: 0.6259 - binary_crossentropy: 0.6259
# Epoch 24: val_loss did not improve from 0.57822
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6242 - binary_crossentropy: 0.6242 - val_loss: 0.5790 - val_binary_crossentropy: 0.5790 - lr: 0.0010
# Epoch 25/10000
# 71/89 [======================>.......] - ETA: 0s - loss: 0.6159 - binary_crossentropy: 0.6159
# Epoch 25: val_loss improved from 0.57822 to 0.57419, saving model to model_keras.h5
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6176 - binary_crossentropy: 0.6176 - val_loss: 0.5742 - val_binary_crossentropy: 0.5742 - lr: 0.0010
# Epoch 26/10000
# 76/89 [========================>.....] - ETA: 0s - loss: 0.6166 - binary_crossentropy: 0.6166
# Epoch 26: val_loss did not improve from 0.57419
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6091 - binary_crossentropy: 0.6091 - val_loss: 0.5764 - val_binary_crossentropy: 0.5764 - lr: 0.0010
# Epoch 27/10000
# 86/89 [===========================>..] - ETA: 0s - loss: 0.6184 - binary_crossentropy: 0.6184
# Epoch 27: val_loss did not improve from 0.57419
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6205 - binary_crossentropy: 0.6205 - val_loss: 0.5787 - val_binary_crossentropy: 0.5787 - lr: 0.0010
# Epoch 28/10000
# 86/89 [===========================>..] - ETA: 0s - loss: 0.6221 - binary_crossentropy: 0.6221
# Epoch 28: val_loss did not improve from 0.57419
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6258 - binary_crossentropy: 0.6258 - val_loss: 0.5802 - val_binary_crossentropy: 0.5802 - lr: 0.0010
# Epoch 29/10000
# 87/89 [============================>.] - ETA: 0s - loss: 0.6016 - binary_crossentropy: 0.6016
# Epoch 29: val_loss did not improve from 0.57419
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6021 - binary_crossentropy: 0.6021 - val_loss: 0.5792 - val_binary_crossentropy: 0.5792 - lr: 0.0010
# Epoch 30/10000
# 87/89 [============================>.] - ETA: 0s - loss: 0.6014 - binary_crossentropy: 0.6014
# Epoch 30: val_loss improved from 0.57419 to 0.57143, saving model to model_keras.h5
# 89/89 [==============================] - 0s 4ms/step - loss: 0.6019 - binary_crossentropy: 0.6019 - val_loss: 0.5714 - val_binary_crossentropy: 0.5714 - lr: 0.0010
# Epoch 31/10000
# 79/89 [=========================>....] - ETA: 0s - loss: 0.6254 - binary_crossentropy: 0.6254
# Epoch 31: val_loss did not improve from 0.57143
# 89/89 [==============================] - 0s 4ms/step - loss: 0.6238 - binary_crossentropy: 0.6238 - val_loss: 0.5714 - val_binary_crossentropy: 0.5714 - lr: 0.0010
# Epoch 32/10000
# 85/89 [===========================>..] - ETA: 0s - loss: 0.6240 - binary_crossentropy: 0.6240
# Epoch 32: val_loss did not improve from 0.57143
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6239 - binary_crossentropy: 0.6239 - val_loss: 0.5777 - val_binary_crossentropy: 0.5777 - lr: 0.0010
# Epoch 33/10000
# 79/89 [=========================>....] - ETA: 0s - loss: 0.6284 - binary_crossentropy: 0.6284
# Epoch 33: val_loss did not improve from 0.57143
# 89/89 [==============================] - 0s 4ms/step - loss: 0.6229 - binary_crossentropy: 0.6229 - val_loss: 0.5778 - val_binary_crossentropy: 0.5778 - lr: 0.0010
# Epoch 34/10000
# 88/89 [============================>.] - ETA: 0s - loss: 0.6197 - binary_crossentropy: 0.6197
# Epoch 34: val_loss did not improve from 0.57143
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6194 - binary_crossentropy: 0.6194 - val_loss: 0.5802 - val_binary_crossentropy: 0.5802 - lr: 0.0010
# Epoch 35/10000
# 73/89 [=======================>......] - ETA: 0s - loss: 0.6208 - binary_crossentropy: 0.6208
# Epoch 35: val_loss did not improve from 0.57143
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6172 - binary_crossentropy: 0.6172 - val_loss: 0.5744 - val_binary_crossentropy: 0.5744 - lr: 0.0010
# Epoch 36/10000
# 71/89 [======================>.......] - ETA: 0s - loss: 0.6089 - binary_crossentropy: 0.6089
# Epoch 36: val_loss did not improve from 0.57143
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6155 - binary_crossentropy: 0.6155 - val_loss: 0.5749 - val_binary_crossentropy: 0.5749 - lr: 1.0000e-04
# Epoch 37/10000
# 85/89 [===========================>..] - ETA: 0s - loss: 0.5999 - binary_crossentropy: 0.5999
# Epoch 37: val_loss did not improve from 0.57143
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6052 - binary_crossentropy: 0.6052 - val_loss: 0.5739 - val_binary_crossentropy: 0.5739 - lr: 1.0000e-04
# Epoch 38/10000
# 85/89 [===========================>..] - ETA: 0s - loss: 0.6091 - binary_crossentropy: 0.6091
# Epoch 38: val_loss did not improve from 0.57143
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6059 - binary_crossentropy: 0.6059 - val_loss: 0.5752 - val_binary_crossentropy: 0.5752 - lr: 1.0000e-04
# Epoch 39/10000
# 83/89 [==========================>...] - ETA: 0s - loss: 0.6211 - binary_crossentropy: 0.6211
# Epoch 39: val_loss did not improve from 0.57143
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6202 - binary_crossentropy: 0.6202 - val_loss: 0.5750 - val_binary_crossentropy: 0.5750 - lr: 1.0000e-04
# Epoch 40/10000
# 88/89 [============================>.] - ETA: 0s - loss: 0.6186 - binary_crossentropy: 0.6186
# Epoch 40: val_loss did not improve from 0.57143
# Restoring model weights from the end of the best epoch: 30.
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 89/89 [==============================] - 0s 4ms/step - loss: 0.6168 - binary_crossentropy: 0.6168 - val_loss: 0.5737 - val_binary_crossentropy: 0.5737 - lr: 1.0000e-04
# Epoch 40: early stopping

# %% [markdown]
# #### スクリプト6-22: モデルの評価

# %%
y_va_pred = model.predict(x_va, batch_size=8, verbose=1)
print("accuracy: {:.4f}".format(accuracy_score(y_va, np.where(y_va_pred>=0.5,1,0))))
# Out:
# 23/23 [==============================] - 0s 1ms/step
# accuracy: 0.7095

# %% [markdown]
# ### ニューラルネットワークの適用例：②埋め込み層ありのネットワークモデル
# #### スクリプト6-23: ファイルの読み込みとデータセット作成

# %%
# ファイル読み込み
df_train = pd.read_csv("../input/titanic/train.csv")

# データセット作成
x_train = df_train[["Pclass", "Age", "Cabin"]]
y_train = df_train[["Survived"]]

# %% [markdown]
# #### スクリプト6-24: 数値データの前処理

# %%
# 欠損値補間
x_train["Age"] = x_train["Age"].fillna(x_train["Age"].mean())

# 正規化
for col in ["Pclass", "Age"]:
    value_min = x_train[col].min()
    value_max = x_train[col].max()
    x_train[col] = (x_train[col] - value_min) / (value_max - value_min)

# %% [markdown]
# #### スクリプト6-25: カテゴリ変数の前処理

# %%
# 欠損値補間
x_train["Cabin"] = x_train["Cabin"].fillna("None")

# label-encoding
le = LabelEncoder()
le.fit(x_train[["Cabin"]])
x_train["Cabin"] = le.transform(x_train["Cabin"])

print(le.classes_)
print("count:", len(le.classes_))
# Out:
# ['A10' 'A14' 'A16' 'A19' 'A20' 'A23' 'A24' 'A26' 'A31' 'A32' 'A34' 'A36'
#  'A5' 'A6' 'A7' 'B101' 'B102' 'B18' 'B19' 'B20' 'B22' 'B28' 'B3' 'B30'
#  'B35' 'B37' 'B38' 'B39' 'B4' 'B41' 'B42' 'B49' 'B5' 'B50' 'B51 B53 B55'
#  'B57 B59 B63 B66' 'B58 B60' 'B69' 'B71' 'B73' 'B77' 'B78' 'B79' 'B80'
#  'B82 B84' 'B86' 'B94' 'B96 B98' 'C101' 'C103' 'C104' 'C106' 'C110' 'C111'
#  'C118' 'C123' 'C124' 'C125' 'C126' 'C128' 'C148' 'C2' 'C22 C26'
#  'C23 C25 C27' 'C30' 'C32' 'C45' 'C46' 'C47' 'C49' 'C50' 'C52' 'C54'
#  'C62 C64' 'C65' 'C68' 'C7' 'C70' 'C78' 'C82' 'C83' 'C85' 'C86' 'C87'
#  'C90' 'C91' 'C92' 'C93' 'C95' 'C99' 'D' 'D10 D12' 'D11' 'D15' 'D17' 'D19'
#  'D20' 'D21' 'D26' 'D28' 'D30' 'D33' 'D35' 'D36' 'D37' 'D45' 'D46' 'D47'
#  'D48' 'D49' 'D50' 'D56' 'D6' 'D7' 'D9' 'E10' 'E101' 'E12' 'E121' 'E17'
#  'E24' 'E25' 'E31' 'E33' 'E34' 'E36' 'E38' 'E40' 'E44' 'E46' 'E49' 'E50'
#  'E58' 'E63' 'E67' 'E68' 'E77' 'E8' 'F E69' 'F G63' 'F G73' 'F2' 'F33'
#  'F38' 'F4' 'G6' 'None' 'T']
# count: 148

# %% [markdown]
# #### スクリプト6-26: 学習データと検証データの分離

# %%
x_train_num, x_train_cat = x_train[["Pclass", "Age"]], x_train[["Cabin"]]

x_num_tr, x_num_va, x_cat_tr, x_cat_va, y_tr, y_va = \
   train_test_split(x_train_num, x_train_cat, y_train, test_size=0.2, stratify=y_train, random_state=123)
print(x_num_tr.shape, x_num_va.shape, x_cat_tr.shape, x_cat_va.shape, y_tr.shape, y_va.shape)
# Out:
# (712, 2) (179, 2) (712, 1) (179, 1) (712, 1) (179, 1)

# %% [markdown]
# #### スクリプト6-27: モデル定義

# %%
def create_model_embedding():
    ################# num
    input_num = Input(shape=(2,))
    layer_num = Dense(10, activation="relu")(input_num)
    layer_num = BatchNormalization()(layer_num)
    layer_num = Dropout(0.2)(layer_num)
    layer_num = Dense(10, activation="relu")(layer_num)

    ################# cat
    input_cat = Input(shape=(1,))
    layer_cat = input_cat[:, 0]
    layer_cat = Embedding(input_dim=148, output_dim=74)(layer_cat)
    layer_cat = Dropout(0.2)(layer_cat)
    layer_cat = Flatten()(layer_cat)

    ################# concat
    hidden_layer = Concatenate()([layer_num, layer_cat])
    hidden_layer = Dense(50, activation="relu")(hidden_layer)
    hidden_layer = BatchNormalization()(hidden_layer)
    hidden_layer = Dropout(0.1)(hidden_layer)
    hidden_layer = Dense(20, activation="relu")(hidden_layer)
    hidden_layer = BatchNormalization()(hidden_layer)
    hidden_layer = Dropout(0.1)(hidden_layer)
    output_layer = Dense(1, activation="sigmoid")(hidden_layer)

    model = Model(inputs=[input_num, input_cat],
                  outputs=output_layer,
                 )

    model.compile(
        optimizer="Adam",
        loss="binary_crossentropy",
        metrics=["binary_crossentropy"],
    )
    
    return model

model = create_model_embedding()
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 2)]                  0         []
#
#  input_4 (InputLayer)        [(None, 1)]                  0         []
#
#  dense_8 (Dense)             (None, 10)                   30        ['input_3[0][0]']
#
#  tf.__operators__.getitem (  (None,)                      0         ['input_4[0][0]']
#  SlicingOpLambda)
#
#  batch_normalization_6 (Bat  (None, 10)                   40        ['dense_8[0][0]']
#  chNormalization)
#
#  embedding (Embedding)       (None, 74)                   10952     ['tf.__operators__.getitem[0][
#                                                                     0]']
#
#  dropout_6 (Dropout)         (None, 10)                   0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 74)                   0         ['embedding[0][0]']
#
#  dense_9 (Dense)             (None, 10)                   110       ['dropout_6[0][0]']
#
#  flatten (Flatten)           (None, 74)                   0         ['dropout_7[0][0]']
#
#  concatenate (Concatenate)   (None, 84)                   0         ['dense_9[0][0]',
#                                                                      'flatten[0][0]']
#
#  dense_10 (Dense)            (None, 50)                   4250      ['concatenate[0][0]']
#
#  batch_normalization_7 (Bat  (None, 50)                   200       ['dense_10[0][0]']
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 50)                   0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dense_11 (Dense)            (None, 20)                   1020      ['dropout_8[0][0]']
#
#  batch_normalization_8 (Bat  (None, 20)                   80        ['dense_11[0][0]']
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 20)                   0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  dense_12 (Dense)            (None, 1)                    21        ['dropout_9[0][0]']
#
# ==================================================================================================
# Total params: 16703 (65.25 KB)
# Trainable params: 16543 (64.62 KB)
# Non-trainable params: 160 (640.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# #### スクリプト6-28: モデルの学習

# %%
seed_everything(seed=123)
model = create_model_embedding()
model.fit(x=[x_num_tr, x_cat_tr],
          y=y_tr,
          validation_data=([x_num_va, x_cat_va], y_va),
          batch_size=8,
          epochs=10000,
          callbacks=[
              ModelCheckpoint(filepath="model_keras_embedding.h5", monitor="val_loss", mode="min", verbose=1, save_best_only=True, save_weights_only=True),
              EarlyStopping(monitor="val_loss", mode="min", min_delta=0, patience=10, verbose=1, restore_best_weights=True),
              ReduceLROnPlateau(monitor="val_loss", mode="min", factor=0.1, patience=5, verbose=1),
          ],
          verbose=1,
         )
# Out:
# Epoch 1/10000
# 73/89 [=======================>......] - ETA: 0s - loss: 0.7891 - binary_crossentropy: 0.7891
# Epoch 1: val_loss improved from inf to 0.65861, saving model to model_keras_embedding.h5
# 89/89 [==============================] - 3s 8ms/step - loss: 0.7850 - binary_crossentropy: 0.7850 - val_loss: 0.6586 - val_binary_crossentropy: 0.6586 - lr: 0.0010
# Epoch 2/10000
# 84/89 [===========================>..] - ETA: 0s - loss: 0.6657 - binary_crossentropy: 0.6657
# Epoch 2: val_loss improved from 0.65861 to 0.65290, saving model to model_keras_embedding.h5
# 89/89 [==============================] - 0s 4ms/step - loss: 0.6631 - binary_crossentropy: 0.6631 - val_loss: 0.6529 - val_binary_crossentropy: 0.6529 - lr: 0.0010
# Epoch 3/10000
# 82/89 [==========================>...] - ETA: 0s - loss: 0.6518 - binary_crossentropy: 0.6518
# Epoch 3: val_loss improved from 0.65290 to 0.64176, saving model to model_keras_embedding.h5
# 89/89 [==============================] - 0s 4ms/step - loss: 0.6440 - binary_crossentropy: 0.6440 - val_loss: 0.6418 - val_binary_crossentropy: 0.6418 - lr: 0.0010
# Epoch 4/10000
# 80/89 [=========================>....] - ETA: 0s - loss: 0.6345 - binary_crossentropy: 0.6345
# Epoch 4: val_loss improved from 0.64176 to 0.61593, saving model to model_keras_embedding.h5
# 89/89 [==============================] - 0s 4ms/step - loss: 0.6320 - binary_crossentropy: 0.6320 - val_loss: 0.6159 - val_binary_crossentropy: 0.6159 - lr: 0.0010
# Epoch 5/10000
# 82/89 [==========================>...] - ETA: 0s - loss: 0.6088 - binary_crossentropy: 0.6088
# Epoch 5: val_loss did not improve from 0.61593
# 89/89 [==============================] - 0s 4ms/step - loss: 0.6064 - binary_crossentropy: 0.6064 - val_loss: 0.6177 - val_binary_crossentropy: 0.6177 - lr: 0.0010
# Epoch 6/10000
# 79/89 [=========================>....] - ETA: 0s - loss: 0.5987 - binary_crossentropy: 0.5987
# Epoch 6: val_loss improved from 0.61593 to 0.58922, saving model to model_keras_embedding.h5
# 89/89 [==============================] - 0s 4ms/step - loss: 0.5930 - binary_crossentropy: 0.5930 - val_loss: 0.5892 - val_binary_crossentropy: 0.5892 - lr: 0.0010
# Epoch 7/10000
# 77/89 [========================>.....] - ETA: 0s - loss: 0.5790 - binary_crossentropy: 0.5790
# Epoch 7: val_loss did not improve from 0.58922
# 89/89 [==============================] - 0s 4ms/step - loss: 0.5855 - binary_crossentropy: 0.5855 - val_loss: 0.6132 - val_binary_crossentropy: 0.6132 - lr: 0.0010
# Epoch 8/10000
# 80/89 [=========================>....] - ETA: 0s - loss: 0.5519 - binary_crossentropy: 0.5519
# Epoch 8: val_loss did not improve from 0.58922
# 89/89 [==============================] - 0s 4ms/step - loss: 0.5578 - binary_crossentropy: 0.5578 - val_loss: 0.6386 - val_binary_crossentropy: 0.6386 - lr: 0.0010
# Epoch 9/10000
# 78/89 [=========================>....] - ETA: 0s - loss: 0.5502 - binary_crossentropy: 0.5502
# Epoch 9: val_loss did not improve from 0.58922
# 89/89 [==============================] - 0s 4ms/step - loss: 0.5514 - binary_crossentropy: 0.5514 - val_loss: 0.6378 - val_binary_crossentropy: 0.6378 - lr: 0.0010
# Epoch 10/10000
# 80/89 [=========================>....] - ETA: 0s - loss: 0.5529 - binary_crossentropy: 0.5529
# Epoch 10: val_loss did not improve from 0.58922
# 89/89 [==============================] - 0s 4ms/step - loss: 0.5538 - binary_crossentropy: 0.5538 - val_loss: 0.6402 - val_binary_crossentropy: 0.6402 - lr: 0.0010
# Epoch 11/10000
# 78/89 [=========================>....] - ETA: 0s - loss: 0.5511 - binary_crossentropy: 0.5511
# Epoch 11: val_loss did not improve from 0.58922
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 89/89 [==============================] - 0s 4ms/step - loss: 0.5571 - binary_crossentropy: 0.5571 - val_loss: 0.6475 - val_binary_crossentropy: 0.6475 - lr: 0.0010
# Epoch 12/10000
# 79/89 [=========================>....] - ETA: 0s - loss: 0.5364 - binary_crossentropy: 0.5364
# Epoch 12: val_loss did not improve from 0.58922
# 89/89 [==============================] - 0s 4ms/step - loss: 0.5269 - binary_crossentropy: 0.5269 - val_loss: 0.6454 - val_binary_crossentropy: 0.6454 - lr: 1.0000e-04
# Epoch 13/10000
# 82/89 [==========================>...] - ETA: 0s - loss: 0.5486 - binary_crossentropy: 0.5486
# Epoch 13: val_loss did not improve from 0.58922
# 89/89 [==============================] - 0s 4ms/step - loss: 0.5563 - binary_crossentropy: 0.5563 - val_loss: 0.6468 - val_binary_crossentropy: 0.6468 - lr: 1.0000e-04
# Epoch 14/10000
# 82/89 [==========================>...] - ETA: 0s - loss: 0.5230 - binary_crossentropy: 0.5230
# Epoch 14: val_loss did not improve from 0.58922
# 89/89 [==============================] - 0s 4ms/step - loss: 0.5262 - binary_crossentropy: 0.5262 - val_loss: 0.6473 - val_binary_crossentropy: 0.6473 - lr: 1.0000e-04
# Epoch 15/10000
# 82/89 [==========================>...] - ETA: 0s - loss: 0.5360 - binary_crossentropy: 0.5360
# Epoch 15: val_loss did not improve from 0.58922
# 89/89 [==============================] - 0s 4ms/step - loss: 0.5330 - binary_crossentropy: 0.5330 - val_loss: 0.6474 - val_binary_crossentropy: 0.6474 - lr: 1.0000e-04
# Epoch 16/10000
# 87/89 [============================>.] - ETA: 0s - loss: 0.5471 - binary_crossentropy: 0.5471
# Epoch 16: val_loss did not improve from 0.58922
# Restoring model weights from the end of the best epoch: 6.
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 89/89 [==============================] - 0s 4ms/step - loss: 0.5497 - binary_crossentropy: 0.5497 - val_loss: 0.6494 - val_binary_crossentropy: 0.6494 - lr: 1.0000e-04
# Epoch 16: early stopping

# %% [markdown]
# #### スクリプト6-29: モデル評価

# %%
y_va_pred = model.predict([x_num_va, x_cat_va], batch_size=8, verbose=1)
print("accuracy: {:.4f}".format(accuracy_score(y_va, np.where(y_va_pred>=0.5,1,0))))
# Out:
# 23/23 [==============================] - 0s 2ms/step
# accuracy: 0.7151

# %% [markdown]
# # 6.3 アンサンブル
# ## 6.3.1 単純平均

# %% [markdown]
# #### スクリプト6-30: 3モデルの予測値を持つデータフレームを乱数で作成

# %%
np.random.seed(123)
df = pd.DataFrame({
    "true": [0]*700 + [1]*300,
    "pred1":np.arange(1000) + np.random.rand(1000)*1200,
    "pred2":np.arange(1000) + np.random.rand(1000)*1000,
    "pred3":np.arange(1000) + np.random.rand(1000)*800,
})
df["pred1"] = np.clip(df["pred1"]/df["pred1"].max(), 0, 1)
df["pred2"] = np.clip(df["pred2"]/df["pred2"].max(), 0, 1)
df["pred3"] = np.clip(df["pred3"]/df["pred3"].max(), 0, 1)

df_train, df_test = train_test_split(df, test_size=0.8, stratify=df["true"], random_state=123)
df_train = df_train.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)
df_train.head()
# Out:
#    true     pred1     pred2     pred3
# 0     1  0.683821  0.874443  0.859939
# 1     0  0.540691  0.113419  0.197144
# 2     0  0.310541  0.334798  0.599304
# 3     0  0.043486  0.170622  0.378528
# 4     0  0.550847  0.354703  0.598860

# %% [markdown]
# #### スクリプト6-31: 単純平均によるアンサンブル

# %%
df_train["pred_ensemble1"] = (df_train["pred1"] + df_train["pred2"] + df_train["pred3"]) / 3
df_train.head()
# Out:
#    true     pred1     pred2     pred3  pred_ensemble1
# 0     1  0.683821  0.874443  0.859939        0.806068
# 1     0  0.540691  0.113419  0.197144        0.283752
# 2     0  0.310541  0.334798  0.599304        0.414881
# 3     0  0.043486  0.170622  0.378528        0.197545
# 4     0  0.550847  0.354703  0.598860        0.501470

# %% [markdown]
# #### スクリプト6-32: アンサンブル用の精度評価関数と、精度評価

# %%
def evaluate_ensemble(input_df, col_pred):
    print("[auc] model1:{:.4f}, model2:{:.4f}, model3:{:.4f} -> ensemble:{:.4f}".format(
        roc_auc_score(input_df["true"], input_df["pred1"]),
        roc_auc_score(input_df["true"], input_df["pred2"]),
        roc_auc_score(input_df["true"], input_df["pred3"]),
        roc_auc_score(input_df["true"], input_df[col_pred]),
    ))

evaluate_ensemble(df_train, col_pred="pred_ensemble1")
# Out:
# [auc] model1:0.8342, model2:0.8671, model3:0.9050 -> ensemble:0.9585

# %% [markdown]
# #### スクリプト6-33: 推論時のアンサンブル処理と、精度評価

# %%
df_test["pred_ensemble1"] = (df_test["pred1"] + df_test["pred2"] + df_test["pred3"]) / 3
evaluate_ensemble(df_test, col_pred="pred_ensemble1")
# Out:
# [auc] model1:0.8086, model2:0.8398, model3:0.8973 -> ensemble:0.9396

# %% [markdown]
# ## 6.3.2 重み付き平均

# %% [markdown]
# #### スクリプト6-34: 重み付き平均によるアンサンブル

# %%
weight = [0.3, 0.3, 0.4]
weight = weight / np.sum(weight)
print(weight)

df_train["pred_ensemble2"] = df_train["pred1"] * weight[0] + \
                             df_train["pred2"] * weight[1] + \
                             df_train["pred3"] * weight[2]
df_train[["true","pred1","pred2","pred3","pred_ensemble2"]].head()
# Out:
# [0.3 0.3 0.4]
#    true     pred1     pred2     pred3  pred_ensemble2
# 0     1  0.683821  0.874443  0.859939        0.811455
# 1     0  0.540691  0.113419  0.197144        0.275091
# 2     0  0.310541  0.334798  0.599304        0.433324
# 3     0  0.043486  0.170622  0.378528        0.215643
# 4     0  0.550847  0.354703  0.598860        0.511209

# %% [markdown]
# #### スクリプト6-35: アンサンブルの精度評価

# %%
evaluate_ensemble(df_train, col_pred="pred_ensemble2")
# Out:
# [auc] model1:0.8342, model2:0.8671, model3:0.9050 -> ensemble:0.9614

# %% [markdown]
# #### スクリプト6-36: 推論時のアンサンブル処理と、精度評価

# %%
df_test["pred_ensemble2"] = df_test["pred1"] * weight[0] + \
                            df_test["pred2"] * weight[1] + \
                            df_test["pred3"] * weight[2]
evaluate_ensemble(df_test, col_pred="pred_ensemble2")
# Out:
# [auc] model1:0.8086, model2:0.8398, model3:0.8973 -> ensemble:0.9420

# %% [markdown]
# ## 6.3.3 スタッキング

# %% [markdown]
# #### スクリプト6-37: スタッキングによるアンサンブル

# %%
from sklearn.linear_model import Lasso

x, y = df_train[["pred1", "pred2", "pred3"]], df_train[["true"]]
oof = np.zeros(len(x))
models = []

cv = list(StratifiedKFold(n_splits=5, shuffle=True, random_state=123).split(x, y))
for nfold in np.arange(5):
    # 学習データと検証データの分離
    idx_tr, idx_va = cv[nfold][0], cv[nfold][1]
    x_tr, y_tr = x.loc[idx_tr, :], y.loc[idx_tr, :]
    x_va, y_va = x.loc[idx_va, :], y.loc[idx_va, :]
    
    # モデル学習
    model = Lasso(alpha=0.01)
    model.fit(x_tr, y_tr)
    models.append(model)
    
    # 検証データの予測値算出
    y_va_pred = model.predict(x_va)
    oof[idx_va] = y_va_pred
    
df_train["pred_ensemble3"] = oof
df_train["pred_ensemble3"] = df_train["pred_ensemble3"].clip(lower=0, upper=1)
df_train[["true","pred1","pred2","pred3","pred_ensemble3"]].head()
# Out:
#    true     pred1     pred2     pred3  pred_ensemble3
# 0     1  0.683821  0.874443  0.859939        0.745020
# 1     0  0.540691  0.113419  0.197144        0.000000
# 2     0  0.310541  0.334798  0.599304        0.206734
# 3     0  0.043486  0.170622  0.378528        0.000000
# 4     0  0.550847  0.354703  0.598860        0.303498

# %% [markdown]
# #### スクリプト6-38: アンサンブルの精度評価

# %%
evaluate_ensemble(df_train, col_pred="pred_ensemble3")
# Out:
# [auc] model1:0.8342, model2:0.8671, model3:0.9050 -> ensemble:0.9577

# %% [markdown]
# #### スクリプト6-39: 推論時のアンサンブル処理と、精度評価

# %%
df_test["pred_ensemble3"] = 0
for model in models:
    df_test["pred_ensemble3"] += model.predict(df_test[["pred1", "pred2", "pred3"]]) / len(models)
df_test["pred_ensemble3"] = df_test["pred_ensemble3"].clip(lower=0, upper=1)
evaluate_ensemble(df_test, col_pred="pred_ensemble3")
# Out:
# [auc] model1:0.8086, model2:0.8398, model3:0.8973 -> ensemble:0.9437
